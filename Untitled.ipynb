# %%
from os import listdir
from os.path import isfile,join

# %%
print(glob.glob('H:/Simon/ST_Transfection_Opt_2018-09-18/'))
# Out:
# ['H:/Simon/ST_Transfection_Opt_2018-09-18/']

# %%
print(x)
# Out:
# ['H:/Simon/ST_Transfection_Opt_2018-09-18/']

# %%
xy = []

# %%
xy = glob.glob(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-bd96b4c7121d> in <module>()
# ----> 1 xy = glob.glob(x)
#
# ~\Anaconda3\lib\glob.py in glob(pathname, recursive)
#      18     zero or more directories and subdirectories.
#      19     """
# ---> 20     return list(iglob(pathname, recursive=recursive))
#      21
#      22 def iglob(pathname, *, recursive=False):
#
# ~\Anaconda3\lib\glob.py in _iglob(pathname, recursive, dironly)
#      38
#      39 def _iglob(pathname, recursive, dironly):
# ---> 40     dirname, basename = os.path.split(pathname)
#      41     if not has_magic(pathname):
#      42         assert not dironly
#
# ~\Anaconda3\lib\ntpath.py in split(p)
#     202     Return tuple (head, tail) where tail is everything after the final slash.
#     203     Either part may be empty."""
# --> 204     p = os.fspath(p)
#     205     seps = _get_bothseps(p)
# ...

# %%
print(xy)
# Out:
# []

# %%
x = os.listdir('H:/Simon/ST_Transfection_Opt_2018-09-18/')
print(len(x))
#print(x)
xx = x
print(len(x))
# Out:
# 22679
# 22679

# %%
for in range(len(x)):
    if ".png" in x[i]:

# %%
well_names = ['B06','B07' , 'B08', 'B09', 'B10', 'B11', 'C06', 'C07', 'C08', 'C09', 'C10', 'C11', 'D06','D07', 'D08', 'D09', 'D10', 'D11'
             ,'E07', 'E08', 'E09', 'E10', 'E11', 'F07', 'F08', 'F09', 'F10', 'F11', 'G07', 'G08', 'G09', 'G10', 'G11' ]

cyc = []
xyx = []


for ii in range(len(well_names)):

    for i in range(len(x)):
        #print(i)
        if well_names[ii] not in x[i]:
            continue
        else: 
            xyx.append(x[i])

    print(len(xyx))
# Out:
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494
# 494

# %%
xyx2 = xyx

for i3 in range(len(xyx)):
    if xyx2[i3] in x: x.remove(xyx2[i3])
        
    print(len(x))
print(len(x))
# Out:
# 837
# 836
# 835
# 834
# 833
# 832
# 831
# 830
# 829
# 828
# 827
# 826
# 825
# 824
# 823
# 822
# 821
# 820
# 819
# 818
# 817
# 816
# 815
# 814
# 813
# 812
# 811
# 810
# 809
# 808
# 807
# 806
# 805
# 804
# 803
# 802
# 801
# 800
# 799
# 798
# 797
# 796
# 795
# 794
# 793
# 792
# 791
# 790
# 789
# 788
# 787
# 786
# 785
# 784
# 783
# 782
# 781
# 780
# 779
# 778
# 777
# 776
# 775
# 774
# 773
# 772
# 771
# 770
# 769
# 768
# 767
# 766
# 765
# 764
# 763
# 762
# 761
# 760
# 759
# 758
# 757
# 756
# 755
# 754
# 753
# 752
# 751
# 750
# 749
# 748
# 747
# 746
# 745
# 744
# 743
# 742
# 741
# 740
# 739
# 738
# 737
# 736
# 735
# 734
# 733
# 732
# 731
# 730
# 729
# 728
# 727
# 726
# 725
# 724
# 723
# 722
# 721
# 720
# 719
# 718
# 717
# 716
# 715
# 714
# 713
# 712
# 711
# 710
# 709
# 708
# 707
# 706
# 705
# 704
# 703
# 702
# 701
# 700
# 699
# 698
# 697
# 696
# 695
# 694
# 693
# 692
# 691
# 690
# 689
# 688
# 687
# 686
# 685
# 684
# 683
# 682
# 681
# 680
# 679
# 678
# 677
# 676
# 675
# 674
# 673
# 672
# ...

# %%
well_names_2 = ['E06', 'F06']
b = []

for ii in range(len(well_names_2)):

    for i in range(len(x)):
        #print(i)
        if well_names_2[ii] not in x[i]:
            continue
        else: 
            b.append(x[i])

print(b)
print(len(b))
#print(x)
# Out:
# ['20180918_ST_Transfection_Opt_E06_1.tif', '20180918_ST_Transfection_Opt_E06_1_GFP.tif', '20180918_ST_Transfection_Opt_E06_1_DAPI.tif', '20180918_ST_Transfection_Opt_E06_2.tif', '20180918_ST_Transfection_Opt_E06_2_GFP.tif', '20180918_ST_Transfection_Opt_E06_2_DAPI.tif', '20180918_ST_Transfection_Opt_E06_3.tif', '20180918_ST_Transfection_Opt_E06_3_DAPI.tif', '20180918_ST_Transfection_Opt_E06_3_GFP.tif', '20180918_ST_Transfection_Opt_E06_4.tif', '20180918_ST_Transfection_Opt_E06_4_GFP.tif', '20180918_ST_Transfection_Opt_E06_4_DAPI.tif', '20180918_ST_Transfection_Opt_E06_5.tif', '20180918_ST_Transfection_Opt_E06_5_DAPI.tif', '20180918_ST_Transfection_Opt_E06_5_GFP.tif', '20180918_ST_Transfection_Opt_E06_6.tif', '20180918_ST_Transfection_Opt_E06_6_GFP.tif', '20180918_ST_Transfection_Opt_E06_6_DAPI.tif', '20180918_ST_Transfection_Opt_E06_7.tif', '20180918_ST_Transfection_Opt_E06_7_GFP.tif', '20180918_ST_Transfection_Opt_E06_7_DAPI.tif', '20180918_ST_Transfection_Opt_E06_8.tif', '20180918_
# ...
