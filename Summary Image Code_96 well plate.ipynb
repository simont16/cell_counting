# %%
from glob import glob
import os 
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec


file_path =  os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection','ST_Transfection_Opt_2018-09-18' )
save_path = os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection')

print(file_path)

fig, (  (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10)
      , (ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20)
      , (ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30)
      , (ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40)
      , (ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50)
      , (ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60)
     ) = plt.subplots(6, 10)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20,
       ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30, ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40,
       ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50, ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60]


files = glob(file_path + '/' + '*png')
new_files = sorted(files)
#print(new_files)

files = glob(file_path + '/' + '*png')

for i5 in range(len(files)):
    files[i5] = files[i5].lstrip(save_path)
    files[i5] = files[i5].rstrip('.png')
    files[i5] = re.sub(r'^2018-09-18\\', '', files[i5])
    
file_names = sorted(files)

for i in range(len(new_files)):
    img = mpimg.imread(new_files[i])
    axes[i].imshow(img)
    axes[i].set_title(file_names[i], fontsize = 3, verticalalignment = 'bottom' )
    axes[i].xaxis.set_visible(False)
    axes[i].yaxis.set_visible(False)

plt.subplots_adjust(wspace = 0.1, hspace = 0.1)    
plt.axis('off')
plt.savefig(os.path.join(save_path, 'summary_image.tiff', dpi = 1600)
plt.show()
# Out:
#   File "<ipython-input-3-06d20d09180f>", line 49
#     plt.show()
#       ^
# SyntaxError: invalid syntax

# %%
from glob import glob
import os 
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec


file_path =  os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection','ST_Transfection_Opt_2018-09-18' )
save_path = os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection')

print(file_path)

fig, (  (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10)
      , (ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20)
      , (ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30)
      , (ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40)
      , (ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50)
      , (ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60)
     ) = plt.subplots(6, 10)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20,
       ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30, ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40,
       ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50, ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60]


files = glob(file_path + '/' + '*png')
new_files = sorted(files)
#print(new_files)

files = glob(file_path + '/' + '*png')

for i5 in range(len(files)):
    files[i5] = files[i5].lstrip(save_path)
    files[i5] = files[i5].rstrip('.png')
    files[i5] = re.sub(r'^2018-09-18\\', '', files[i5])
    
file_names = sorted(files)

for i in range(len(new_files)):
    img = mpimg.imread(new_files[i])
    axes[i].imshow(img)
    axes[i].set_title(file_names[i], fontsize = 3, verticalalignment = 'bottom' )
    axes[i].xaxis.set_visible(False)
    axes[i].yaxis.set_visible(False)
# Out:
# C:\Dropbox (UCL - SWC)\Simon Data Files\Simon\Data\Opt_Transfection\ST_Transfection_Opt_2018-09-18

# %%
from glob import glob
import os 
import re
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec


file_path =  os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection','ST_Transfection_Opt_2018-09-18' )
save_path = os.path.join('C:', os.sep ,'Dropbox (UCL - SWC)', 'Simon Data Files', 'Simon', 'Data', 'Opt_Transfection')

print(file_path)

fig, (  (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10)
      , (ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20)
      , (ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30)
      , (ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40)
      , (ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50)
      , (ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60)
     ) = plt.subplots(6, 10)
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20,
       ax21, ax22, ax23, ax24, ax25, ax26, ax27, ax28, ax29, ax30, ax31, ax32, ax33, ax34, ax35, ax36, ax37, ax38, ax39, ax40,
       ax41, ax42, ax43, ax44, ax45, ax46, ax47, ax48, ax49, ax50, ax51, ax52, ax53, ax54, ax55, ax56, ax57, ax58, ax59, ax60]


files = glob(file_path + '/' + '*png')
new_files = sorted(files)
#print(new_files)

files = glob(file_path + '/' + '*png')

for i5 in range(len(files)):
    files[i5] = files[i5].lstrip(save_path)
    files[i5] = files[i5].rstrip('.png')
    files[i5] = re.sub(r'^2018-09-18\\', '', files[i5])
    
file_names = sorted(files)

for i in range(len(new_files)):
    img = mpimg.imread(new_files[i])
    axes[i].imshow(img)
    axes[i].set_title(file_names[i], fontsize = 3, verticalalignment = 'bottom' )
    axes[i].xaxis.set_visible(False)
    axes[i].yaxis.set_visible(False)

plt.subplots_adjust(wspace = 0.1, hspace = 0.1)    
plt.axis('off')
plt.savefig(os.path.join(save_path, 'summary_image.tiff'), dpi = 1600)
# Out:
# C:\Dropbox (UCL - SWC)\Simon Data Files\Simon\Data\Opt_Transfection\ST_Transfection_Opt_2018-09-18

# %%
# Out:
# 'G08.png'
